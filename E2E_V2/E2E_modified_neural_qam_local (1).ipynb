# %%
# %load_ext autoreload
# %autoreload 2

# %%
import math
from fractions import Fraction

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from surrogate_matlab import *
from fda_rof_funcs_v2 import *
import torch
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.set_default_dtype(torch.float64)

print("device:", device)
# Out:
# device: cuda

# %%
import itertools
import matplotlib.pyplot as plt
import torch


@torch.no_grad()
def plot_learned_constellation(mapper, ml, device=None, annotate=True, title=None):
    """
    Plot learned constellation of NeuralQAMMapper.

    mapper expects input shape [B, Ns, ml]
    """
    if device is None:
        device = next(mapper.parameters()).device

    mapper.eval()

    # all possible bit patterns: [M, ml]
    patterns = list(itertools.product([0, 1], repeat=ml))
    bits = torch.tensor(patterns, dtype=torch.float64, device=device)

    # add fake batch and symbol dimensions -> [1, M, ml]
    bits = bits.unsqueeze(0)

    # mapper output: [1, M]
    sym = mapper(bits)[0]

    sym_np = sym.detach().cpu().numpy()
    xs = sym_np.real
    ys = sym_np.imag

    plt.figure(figsize=(6, 6))
    plt.scatter(xs, ys, s=80)

    if annotate:
        for i, b in enumerate(patterns):
            label = "".join(str(v) for v in b)
            plt.text(xs[i] + 0.02, ys[i] + 0.02, label, fontsize=8)

    plt.axhline(0, linewidth=1)
    plt.axvline(0, linewidth=1)
    plt.xlabel("In-phase")
    plt.ylabel("Quadrature")
    plt.title(title or f"Learned Constellation ({2**ml}-ary)")
    plt.grid(True)
    plt.axis("equal")
    plt.show()

# %%
class FDAROFSurrogateWithRRC(nn.Module):
    def __init__(self,
                 Rt: float,
                 init_a1: float,
                 init_b1: float,
                 init_a2: float,
                 init_b2: float,
                 init_k: float,
                 OFDM_bandwidth: float = 5e9,
                 G: float = 2e9,
                 sps: int = 8,
                 roll: float = 0.1,
                 span: int = 64,
                 num_taps: int = 63,
                 snr_db: float = 10.0):
        super().__init__()

        self.da = ContinuousDABlockTorch(
            Rt=Rt,
            init_a1=init_a1,
            init_b1=init_b1,
            init_a2=init_a2,
            init_b2=init_b2,
        )
        self.k_param = PositiveScalar(init_k)

        self.cfg = add_discrete_freqs_to_fdm_config(
            build_fdm_config_from_rt(
                Rt=Rt,
                OFDM_bandwidth=OFDM_bandwidth,
                G=G,
                sps=sps,
            )
        )

        self.sps = sps
        self.roll = roll
        self.span = span
        self.num_taps = num_taps
        self.snr_db = snr_db

    @property
    def k(self):
        return self.k_param.value

    def forward(self, ofdm_sig: torch.Tensor):
        # 1) continuous DA mod, ofdm_sig is normalized first before DA mod
        sig_n1, sig_n2, mod_aux = self.da.mod(ofdm_sig)
        

        # 2) RRC TX
        tx_rrc_1 = apply_rrc_tx_torch(sig_n1, beta=self.roll, sps=self.sps, span=self.span)
        tx_rrc_2 = apply_rrc_tx_torch(sig_n2, beta=self.roll, sps=self.sps, span=self.span)

        # 3) TX-side resample
        tx1, tx2 = branch_resample_tx_from_cfg(
            tx_rrc_1, tx_rrc_2, self.cfg, num_taps=self.num_taps
        )

        # save original branch lengths after TX resample, matching original RX cropping
        L_sig_inner = tx1.numel()
        L_sig_outer = tx2.numel()
        tx1 = complex_awgn(tx1, self.snr_db)
        tx2 = complex_awgn(tx2, self.snr_db)
        
        # 4) FDM combine
        tx_fdm, fdm_aux = fdm_combine_from_cfg(
            tx1, tx2, self.k, self.cfg, length_mode="pad_to_max"
        )

        # 5) AWGN on combined signal

        ## Receiver
        # 6) FDM separate
        rx1_mix, rx2_mix = fdm_separate_from_cfg(
            tx_fdm, self.k, self.cfg
        )

        # 7) crop back to original branch lengths
        rx1_mix = rx1_mix[:L_sig_inner]
        rx2_mix = rx2_mix[:L_sig_outer]

        # 8) inverse resample
        rx1_rs, rx2_rs = branch_resample_rx_from_cfg(
            rx1_mix, rx2_mix, self.cfg, num_taps=self.num_taps
        )

        # 9) RRC RX
        rx1_rrc = apply_rrc_rx_torch(rx1_rs, beta=self.roll, sps=self.sps, span=self.span)
        rx2_rrc = apply_rrc_rx_torch(rx2_rs, beta=self.roll, sps=self.sps, span=self.span)

        # 10) downsample by sps, matching original code's [::sps]
        rx1_sym = rx1_rrc[::self.sps]
        rx2_sym = rx2_rrc[::self.sps]

        # 11) crop/pad back to DA-demod expected lengths
        rx1_sym = pad_or_crop_to_length(rx1_sym, sig_n1.numel())
        rx2_sym = pad_or_crop_to_length(rx2_sym, sig_n2.numel())

        # 12) continuous DA demod with scale recovery
        x_hat, rx_seg1, rx_seg2, demod_aux = self.da.demod(
            rx1_sym, rx2_sym,
            scale1=mod_aux["scale1"],
            scale2=mod_aux["scale2"],
        )

        aux = {
            "cfg": self.cfg,
            "mod_aux": mod_aux,
            "fdm_aux": fdm_aux,
            "demod_aux": demod_aux,
            "sig_n1": sig_n1,
            "sig_n2": sig_n2,
            "tx_rrc_1": tx_rrc_1,
            "tx_rrc_2": tx_rrc_2,
            "tx1": tx1,
            "tx2": tx2,
            "rx1_rs": rx1_rs,
            "rx2_rs": rx2_rs,
            "rx1_rrc": rx1_rrc,
            "rx2_rrc": rx2_rrc,
            "rx1_sym": rx1_sym,
            "rx2_sym": rx2_sym,
            "tx_fdm": tx_fdm,
            "rx_fdm": tx_fdm,
        }

        return x_hat, rx_seg1, rx_seg2, aux

# %%
# =========================================================
# Complex-gain aligned symbol-level SNR
# =========================================================

def normalize_unit_power_complex(x: torch.Tensor, eps=1e-12):
    """
    x: complex tensor, arbitrary shape
    normalize average power to 1
    """
    p = torch.mean(torch.abs(x) ** 2)
    return x / torch.sqrt(p + eps)


def complex_mmse_gain(tx: torch.Tensor, rx: torch.Tensor, eps=1e-12):
    """
    Find complex scalar h minimizing || h*tx - rx ||^2

    tx, rx: complex tensors with same shape
    return:
        h      : complex scalar
        tx_n   : normalized tx
        rx_n   : normalized rx
    """
    tx_n = normalize_unit_power_complex(tx, eps)
    rx_n = normalize_unit_power_complex(rx, eps)

    denom = torch.sum(torch.abs(tx_n) ** 2).real + eps
    numer = torch.sum(torch.conj(tx_n) * rx_n)
    h = numer / denom
    return h, tx_n, rx_n


def snr_db_complex_gain(tx: torch.Tensor, rx: torch.Tensor, eps=1e-12):
    """
    Complex-gain aligned SNR in dB.

    tx, rx: complex tensors with same shape
    return:
        snr_db : differentiable scalar tensor
        aux    : dict with diagnostics
    """
    h, tx_n, rx_n = complex_mmse_gain(tx, rx, eps=eps)

    ref = h * tx_n
    err = rx_n - ref

    ps = torch.mean(torch.abs(ref) ** 2)
    pn = torch.mean(torch.abs(err) ** 2)

    snr_lin = ps / (pn + eps)
    snr_db = 10.0 * torch.log10(snr_lin + eps)

    aux = {
        "h": h.detach(),
        "ps": ps.detach().item(),
        "pn": pn.detach().item(),
        "snr_lin": snr_lin.detach().item(),
        "snr_db": snr_db.detach().item(),
    }
    return snr_db, aux

# %%
# =========================================================
# End-to-end neural QAM mapper/demapper around FDA-RoF surrogate
# =========================================================

def bits_to_symbol_blocks_torch(bits, ml):
    """
    bits: [B, total_bits] or [total_bits]
    return: [B, num_symbols, ml]
    """
    if bits.dim() == 1:
        bits = bits.unsqueeze(0)
    B, total_bits = bits.shape
    if total_bits % ml != 0:
        raise ValueError(f"total_bits={total_bits} not divisible by ml={ml}")
    return bits.reshape(B, total_bits // ml, ml)


def add_cp_torch(x_freq, gilen):
    """
    x_freq: [B, fftlen, nd] complex
    return: [B, fftlen+gilen, nd]
    """
    cp = x_freq[:, -gilen:, :]
    return torch.cat([cp, x_freq], dim=1)


def remove_cp_torch(x_td_cp, gilen):
    """
    x_td_cp: [B, fftlen+gilen, nd] complex
    """
    return x_td_cp[:, gilen:, :]


def flatten_fortran_last2(x):
    """
    For tensor [B, A, C], emulate numpy reshape(..., order='F') over the last two dims.
    Output: [B, A*C]
    """
    return x.transpose(1, 2).reshape(x.shape[0], -1)


def unflatten_fortran_last2(x, A, C):
    """
    Inverse of flatten_fortran_last2.
    x: [B, A*C] -> [B, A, C]
    """
    B = x.shape[0]
    return x.reshape(B, C, A).transpose(1, 2)


class NeuralQAMMapper(nn.Module):
    """
    Bit block (ml bits) -> one complex symbol.
    """
    def __init__(self, ml, hidden=64):
        super().__init__()
        self.ml = ml
        self.net = nn.Sequential(
            nn.Linear(ml, hidden),
            nn.GELU(),
            nn.Linear(hidden, hidden),
            nn.GELU(),
            nn.Linear(hidden, 2),
        )

    def forward(self, bits_block):
        """
        bits_block: [B, Ns, ml] in {0,1}
        return: complex symbols [B, Ns]
        """
        B, Ns, ml = bits_block.shape
        x = bits_block.reshape(B * Ns, ml)
        y = self.net(x)
        y = y.reshape(B, Ns, 2)

        sym = torch.complex(y[..., 0], y[..., 1])

        # normalize average symbol power to 1 over the batch
        power = torch.mean(torch.abs(sym) ** 2)
        sym = sym / torch.sqrt(power + 1e-12)
        return sym


class NeuralQAMDemapper(nn.Module):
    """
    One complex symbol -> ml bit logits.
    """
    def __init__(self, ml, hidden=64):
        super().__init__()
        self.ml = ml
        self.net = nn.Sequential(
            nn.Linear(2, hidden),
            nn.GELU(),
            nn.Linear(hidden, hidden),
            nn.GELU(),
            nn.Linear(hidden, ml),
        )

    def forward(self, symbols):
        """
        symbols: [B, Ns] complex
        return: logits [B, Ns, ml]
        """
        x = torch.stack([symbols.real, symbols.imag], dim=-1)
        B, Ns, _ = x.shape
        y = self.net(x.reshape(B * Ns, 2))
        return y.reshape(B, Ns, self.ml)


class OFDMModulatorTorch(nn.Module):
    """
    Neural QAM symbols -> OFDM serial waveform
    """
    def __init__(self, cfg=OFDM_CFG):
        super().__init__()
        self.cfg = cfg
        self.para = cfg["para"]
        self.fftlen = cfg["fftlen"]
        self.nd = cfg["nd"]
        self.gilen = cfg["gilen"]
        self.fftlen2 = cfg["fftlen2"]

        if self.para != self.fftlen:
            raise NotImplementedError(
                "Current torch OFDM wrapper assumes para == fftlen, "
                "matching your current notebook setting."
            )

    def forward(self, qam_symbols):
        """
        qam_symbols: [B, para*nd] complex
        return:
            ofdm_serial: [B, fftlen2*nd] complex
            aux: dict
        """
        B, Ns = qam_symbols.shape
        expected = self.para * self.nd
        if Ns != expected:
            raise ValueError(f"qam_symbols has {Ns} symbols, expected {expected}")

        x_freq = unflatten_fortran_last2(qam_symbols, self.fftlen, self.nd)  # [B, fftlen, nd]
        y_td = torch.fft.ifft(x_freq, n=self.fftlen, dim=1)
        y_cp = add_cp_torch(y_td, self.gilen)
        serial = flatten_fortran_last2(y_cp)

        aux = {
            "x_freq": x_freq,
            "y_td": y_td,
            "y_cp": y_cp,
        }
        return serial, aux


class OFDMDemodulatorTorch(nn.Module):
    """
    OFDM serial waveform -> recovered complex QAM symbols
    """
    def __init__(self, cfg=OFDM_CFG):
        super().__init__()
        self.cfg = cfg
        self.para = cfg["para"]
        self.fftlen = cfg["fftlen"]
        self.nd = cfg["nd"]
        self.gilen = cfg["gilen"]
        self.fftlen2 = cfg["fftlen2"]

        if self.para != self.fftlen:
            raise NotImplementedError(
                "Current torch OFDM wrapper assumes para == fftlen, "
                "matching your current notebook setting."
            )

    def forward(self, ofdm_serial):
        """
        ofdm_serial: [B, fftlen2*nd] complex
        return:
            qam_symbols_hat: [B, para*nd] complex
            aux: dict
        """
        B, L = ofdm_serial.shape
        expected = self.fftlen2 * self.nd
        if L != expected:
            raise ValueError(f"ofdm_serial length {L}, expected {expected}")

        y_cp = unflatten_fortran_last2(ofdm_serial, self.fftlen2, self.nd)   # [B, fftlen2, nd]
        y_td = remove_cp_torch(y_cp, self.gilen)                              # [B, fftlen, nd]
        x_freq_hat = torch.fft.fft(y_td, n=self.fftlen, dim=1)
        qam_hat = flatten_fortran_last2(x_freq_hat)

        aux = {
            "y_cp": y_cp,
            "y_td": y_td,
            "x_freq_hat": x_freq_hat,
        }
        return qam_hat, aux


class EndToEndNeuralFDAROF(nn.Module):
    """
    bits -> neural mapper -> OFDM mod -> FDA-RoF surrogate -> OFDM demod -> neural demapper
    """
    def __init__(
        self,
        Rt: float,
        init_a1: float,
        init_b1: float,
        init_a2: float,
        init_b2: float,
        init_k: float,
        mapper_hidden: int = 64,
        demapper_hidden: int = 64,
        cfg=OFDM_CFG,
        OFDM_bandwidth: float = 5e9,
        G: float = 2e9,
        sps: int = 8,
        roll: float = 0.1,
        span: int = 64,
        num_taps: int = 63,
        snr_db: float = 24.0,
    ):
        super().__init__()
        self.cfg = cfg
        self.ml = cfg["ml"]
        self.total_bits = cfg["para"] * cfg["nd"] * cfg["ml"]
        self.num_symbols = cfg["para"] * cfg["nd"]

        self.mapper = NeuralQAMMapper(self.ml, hidden=mapper_hidden)
        self.ofdm_mod = OFDMModulatorTorch(cfg=cfg)

        self.channel = FDAROFSurrogateWithRRC(
            Rt=Rt,
            init_a1=init_a1,
            init_b1=init_b1,
            init_a2=init_a2,
            init_b2=init_b2,
            init_k=init_k,
            OFDM_bandwidth=OFDM_bandwidth,
            G=G,
            sps=sps,
            roll=roll,
            span=span,
            num_taps=num_taps,
            snr_db=snr_db,
        )

        self.ofdm_demod = OFDMDemodulatorTorch(cfg=cfg)
        self.demapper = NeuralQAMDemapper(self.ml, hidden=demapper_hidden)

    def forward(self, bits):
        """
        bits: [B, total_bits] float tensor with values 0/1
        """
        if bits.dim() == 1:
            bits = bits.unsqueeze(0)

        bits_block = bits_to_symbol_blocks_torch(bits, self.ml)  # [B, Ns, ml]

        tx_qam = self.mapper(bits_block)                         # [B, Ns]
        tx_ofdm, tx_aux = self.ofdm_mod(tx_qam)                  # [B, L]

        rx_ofdm_list = []
        ch_aux_list = []
        for b in range(tx_ofdm.shape[0]):
            x_hat, rx_seg1, rx_seg2, aux = self.channel(tx_ofdm[b])
            rx_ofdm_list.append(x_hat)
            ch_aux_list.append({
                "rx_seg1": rx_seg1,
                "rx_seg2": rx_seg2,
                "aux": aux,
            })
        rx_ofdm = torch.stack(rx_ofdm_list, dim=0)              # [B, L]

        rx_qam, rx_aux = self.ofdm_demod(rx_ofdm)               # [B, Ns]
        bit_logits = self.demapper(rx_qam)                      # [B, Ns, ml]

        aux = {
            "bits_block": bits_block,
            "tx_qam": tx_qam,
            "tx_ofdm": tx_ofdm,
            "tx_aux": tx_aux,
            "rx_ofdm": rx_ofdm,
            "rx_qam": rx_qam,
            "rx_aux": rx_aux,
            "channel_aux_list": ch_aux_list,
        }
        return bit_logits, aux


def sample_random_bits_batch(batch_size, cfg=OFDM_CFG, device=None, seed=None):
    if seed is not None:
        np.random.seed(seed)

    total_bits = cfg["para"] * cfg["nd"] * cfg["ml"]
    bits = np.random.randint(0, 2, size=(batch_size, total_bits), dtype=int)
    bits = torch.from_numpy(bits).to(torch.float64)
    if device is not None:
        bits = bits.to(device)
    return bits


def load_parabits_tensor(parabits_path="../Baseline/parabits.mat", cfg=OFDM_CFG, device=None):
    bits = load_parabits_mat(parabits_path).reshape(-1)
    expected = cfg["para"] * cfg["nd"] * cfg["ml"]
    if bits.size != expected:
        raise ValueError(f"parabits length={bits.size}, expected={expected}")
    bits = torch.from_numpy(bits.astype(np.float64)).unsqueeze(0)
    if device is not None:
        bits = bits.to(device)
    return bits


def bit_error_rate_from_logits(bit_logits, target_bits):
    """
    bit_logits: [B, Ns, ml]
    target_bits: [B, total_bits]
    """
    pred = (torch.sigmoid(bit_logits) >= 0.5).to(torch.float64)
    tgt = bits_to_symbol_blocks_torch(target_bits, bit_logits.shape[-1]).to(torch.float64)
    ber = torch.mean((pred != tgt).to(torch.float64))
    return ber.item()


def compute_e2e_bce_loss(model, bits):
    """
    Main end-to-end loss: bit-level BCE after neural demapper.
    Also report waveform/qam diagnostics.
    """
    bit_logits, aux = model(bits)

    target = bits_to_symbol_blocks_torch(bits, model.ml).to(bit_logits.dtype)
    bce = F.binary_cross_entropy_with_logits(bit_logits, target)

    ber = bit_error_rate_from_logits(bit_logits, bits)

    tx_qam = aux["tx_qam"]
    rx_qam = aux["rx_qam"]
    qam_mse = torch.mean(torch.abs(tx_qam - rx_qam) ** 2)

    tx_ofdm = aux["tx_ofdm"]
    rx_ofdm = aux["rx_ofdm"]
    ofdm_mse = torch.mean(torch.abs(tx_ofdm - rx_ofdm) ** 2)

    stats = {
        "loss": bce.detach().item(),
        "ber": ber,
        "qam_mse": qam_mse.detach().item(),
        "ofdm_mse": ofdm_mse.detach().item(),
    }

    # expose current learned physical parameters too
    stats["a1"] = model.channel.da.a1.item()
    stats["b1"] = model.channel.da.b1.item()
    stats["a2"] = model.channel.da.a2.item()
    stats["b2"] = model.channel.da.b2.item()
    stats["k"] = model.channel.k.item()

    return bce, stats
def compute_e2e_joint_loss(model, bits, lambda_sym=0.01):
    """
    Joint loss:
        L = L_bit + lambda_sym * L_sym
    where
        L_bit = BCEWithLogits on bits
        L_sym = - SNR_sym_dB
    """
    bit_logits, aux = model(bits)

    # -----------------------------------------------------
    # 1) bit-level BCE loss
    # -----------------------------------------------------
    target = bits_to_symbol_blocks_torch(bits, model.ml).to(bit_logits.dtype)
    bit_loss = F.binary_cross_entropy_with_logits(bit_logits, target)

    ber = bit_error_rate_from_logits(bit_logits, bits)

    # -----------------------------------------------------
    # 2) symbol-level SNR after OFDM demod
    # -----------------------------------------------------
    tx_ofdm = aux["tx_ofdm"]   # [B, Ns] complex
    rx_ofdm = aux["rx_ofdm"]   # [B, Ns] complex
    tx_qam = aux["tx_qam"]       # [B, Ns] complex
    rx_qam = aux["rx_qam"]       # [B, Ns] complex

    snr_sym_db, snr_aux = snr_db_complex_gain(
        tx_ofdm.reshape(-1),
        rx_ofdm.reshape(-1),
    )

    # auxiliary loss: maximize SNR <=> minimize negative SNR
    sym_loss = -snr_sym_db

    # -----------------------------------------------------
    # 3) total loss
    # -----------------------------------------------------
    total_loss = bit_loss + lambda_sym * sym_loss

    # -----------------------------------------------------
    # 4) diagnostics
    # -----------------------------------------------------
    qam_mse = torch.mean(torch.abs(tx_qam - rx_qam) ** 2)

    ofdm_mse = torch.mean(torch.abs(tx_ofdm - rx_ofdm) ** 2)

    stats = {
        "loss": total_loss.detach().item(),
        "bit_loss": bit_loss.detach().item(),
        "sym_loss": sym_loss.detach().item(),
        "ber": ber,
        "snr_sym_db": snr_aux["snr_db"],
        "qam_mse": qam_mse.detach().item(),
        "ofdm_mse": ofdm_mse.detach().item(),
        "a1": model.channel.da.a1.item(),
        "b1": model.channel.da.b1.item(),
        "a2": model.channel.da.a2.item(),
        "b2": model.channel.da.b2.item(),
        "k": model.channel.k.item(),
    }

    return total_loss, stats

@torch.no_grad()
def validate_e2e_on_parabits(model, parabits_path="../Baseline/parabits.mat", cfg=OFDM_CFG, device=None):
    if device is None:
        device = next(model.parameters()).device
    bits = load_parabits_tensor(parabits_path=parabits_path, cfg=cfg, device=device)
    model.eval()
    loss, stats = compute_e2e_bce_loss(model, bits)
    return loss.item(), stats
@torch.no_grad()
def validate_e2e_joint_on_parabits(
    model,
    parabits_path="../Baseline/parabits.mat",
    cfg=OFDM_CFG,
    device=None,
    lambda_sym=0.01,
):
    if device is None:
        device = next(model.parameters()).device

    bits = load_parabits_tensor(
        parabits_path=parabits_path,
        cfg=cfg,
        device=device,
    )

    model.eval()
    loss, stats = compute_e2e_joint_loss(model, bits, lambda_sym=lambda_sym)
    return loss.item(), stats
best_snr_sym = -float("inf")
best_step = -1
import copy
import torch

def train_e2e_neural_modem(
    model,
    num_steps=200,
    batch_size=8,
    lr=1e-3,
    lambda_sym=0.01,
    print_every=20,
    grad_clip=None,
    parabits_path="../Baseline/parabits.mat",
):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    history = {
        "loss": [],
        "bit_loss": [],
        "sym_loss": [],
        "ber": [],
        "snr_sym_db": [],
        "qam_mse": [],
        "ofdm_mse": [],
        "val_loss": [],
        "val_bit_loss": [],
        "val_sym_loss": [],
        "val_ber": [],
        "val_snr_sym_db": [],
        "val_qam_mse": [],
        "val_ofdm_mse": [],
        "a1": [],
        "b1": [],
        "a2": [],
        "b2": [],
        "k": [],
    }

    # -----------------------------
    # best trackers
    # -----------------------------
    best_val_ber = float("inf")
    best_val_ber_step = -1
    best_state_by_ber = None

    best_train_snr_sym = -float("inf")
    best_train_snr_sym_step = -1
    best_state_train_snr = None

    best_val_snr_sym = -float("inf")
    best_val_snr_sym_step = -1
    best_state_val_snr = None

    device = next(model.parameters()).device

    for step in range(1, num_steps + 1):
        model.train()
        optimizer.zero_grad()

        # 如果你之后想换回 random batch，可以打开这段
        # bits = sample_random_bits_batch(
        #     batch_size=batch_size,
        #     cfg=model.cfg,
        #     device=device,
        #     seed=step,
        # )

        bits = load_parabits_tensor(
            parabits_path=parabits_path,
            cfg=model.cfg,
            device=device,
        )

        loss, stats = compute_e2e_joint_loss(
            model,
            bits,
            lambda_sym=lambda_sym,
        )
        loss.backward()

        if grad_clip is not None:
            torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)

        optimizer.step()

        # -----------------------------
        # record train stats
        # -----------------------------
        history["loss"].append(stats["loss"])
        history["bit_loss"].append(stats["bit_loss"])
        history["sym_loss"].append(stats["sym_loss"])
        history["ber"].append(stats["ber"])
        history["snr_sym_db"].append(stats["snr_sym_db"])
        history["qam_mse"].append(stats["qam_mse"])
        history["ofdm_mse"].append(stats["ofdm_mse"])
        history["a1"].append(stats["a1"])
        history["b1"].append(stats["b1"])
        history["a2"].append(stats["a2"])
        history["b2"].append(stats["b2"])
        history["k"].append(stats["k"])

        # -----------------------------
        # update best train snr_sym
        # -----------------------------
        if stats["snr_sym_db"] > best_train_snr_sym:
            best_train_snr_sym = stats["snr_sym_db"]
            best_train_snr_sym_step = step
            best_state_train_snr = copy.deepcopy(model.state_dict())

        # -----------------------------
        # validation
        # -----------------------------
        if step % print_every == 0 or step == 1 or step == num_steps:
            val_loss, val_stats = validate_e2e_joint_on_parabits(
                model,
                parabits_path=parabits_path,
                cfg=model.cfg,
                device=device,
                lambda_sym=lambda_sym,
            )

            history["val_loss"].append(val_loss)
            history["val_bit_loss"].append(val_stats["bit_loss"])
            history["val_sym_loss"].append(val_stats["sym_loss"])
            history["val_ber"].append(val_stats["ber"])
            history["val_snr_sym_db"].append(val_stats["snr_sym_db"])
            history["val_qam_mse"].append(val_stats["qam_mse"])
            history["val_ofdm_mse"].append(val_stats["ofdm_mse"])

            # best by BER
            if val_stats["ber"] < best_val_ber:
                best_val_ber = val_stats["ber"]
                best_val_ber_step = step
                best_state_by_ber = copy.deepcopy(model.state_dict())

            # best by validation snr_sym
            if val_stats["snr_sym_db"] > best_val_snr_sym:
                best_val_snr_sym = val_stats["snr_sym_db"]
                best_val_snr_sym_step = step
                best_state_val_snr = copy.deepcopy(model.state_dict())

            print(
                f"step {step:4d} | "
                f"train_loss={stats['loss']:.6f} | "
                f"bit_loss={stats['bit_loss']:.6f} | "
                f"snr_sym={stats['snr_sym_db']:.4f} dB | "
                f"train_ber={stats['ber']:.6e} | "
                f"val_loss={val_loss:.6f} | "
                f"val_bit_loss={val_stats['bit_loss']:.6f} | "
                f"val_snr_sym={val_stats['snr_sym_db']:.4f} dB | "
                f"val_ber={val_stats['ber']:.6e} | "
                f"best_train_snr={best_train_snr_sym:.4f} dB @ {best_train_snr_sym_step} | "
                f"best_val_snr={best_val_snr_sym:.4f} dB @ {best_val_snr_sym_step} | "
                f"a1={model.channel.da.a1.item():.4f} | "
                f"b1={model.channel.da.b1.item():.4f} | "
                f"a2={model.channel.da.a2.item():.4f} | "
                f"b2={model.channel.da.b2.item():.4f} | "
                f"k={model.channel.k.item():.4f}"
            )

    # -----------------------------
    # save summary into history
    # -----------------------------
    history["best_val_ber"] = best_val_ber
    history["best_val_ber_step"] = best_val_ber_step
    history["best_state_by_ber"] = best_state_by_ber

    history["best_train_snr_sym_db"] = best_train_snr_sym
    history["best_train_snr_sym_step"] = best_train_snr_sym_step
    history["best_state_train_snr"] = best_state_train_snr

    history["best_val_snr_sym_db"] = best_val_snr_sym
    history["best_val_snr_sym_step"] = best_val_snr_sym_step
    history["best_state_val_snr"] = best_state_val_snr

    print("\nTraining finished.")
    print(f"Best train snr_sym = {best_train_snr_sym:.4f} dB at step {best_train_snr_sym_step}")
    print(f"Best val   snr_sym = {best_val_snr_sym:.4f} dB at step {best_val_snr_sym_step}")
    print(f"Best val   BER     = {best_val_ber:.6e} at step {best_val_ber_step}")

    return history

# %%
# =========================================================
# Example: instantiate end-to-end neural modem
# =========================================================
torch.manual_seed(0)
np.random.seed(0)

e2e_model = EndToEndNeuralFDAROF(
    Rt=2.25,
    init_a1=4.0,
    init_b1=1.2,
    init_a2=4.0,
    init_b2=1.0,
    init_k=1.0,
    mapper_hidden=64,
    demapper_hidden=64,
    cfg=OFDM_CFG,
    OFDM_bandwidth=5e9,
    G=2e9,
    sps=8,
    roll=0.1,
    span=64,
    num_taps=63,
    snr_db=16.0,
).to(device)

print("E2E model ready.")
print("total bits per sample:", e2e_model.total_bits)
print("num qam symbols:", e2e_model.num_symbols)
# Out:
# E2E model ready.
# total bits per sample: 61440
# num qam symbols: 10240

# %%
history_e2e = train_e2e_neural_modem(
    e2e_model,
    num_steps=800,
    batch_size=4,
    lr=1e-3,
    lambda_sym=0.01,   # 先从小值开始
    print_every=10,
    grad_clip=2.0,
    parabits_path="../Baseline/parabits.mat",
)
# Out:
# step    1 | train_loss=0.750190 | bit_loss=0.696339 | snr_sym=-5.3851 dB | train_ber=4.891276e-01 | val_loss=0.735164 | val_bit_loss=0.691898 | val_snr_sym=-4.3267 dB | val_ber=4.798177e-01 | best_train_snr=-5.3851 dB @ 1 | best_val_snr=-4.3267 dB @ 1 | a1=4.0011 | b1=1.1994 | a2=3.9991 | b2=1.0007 | k=0.9995
# step   10 | train_loss=0.533116 | bit_loss=0.652950 | snr_sym=11.9834 dB | train_ber=3.461263e-01 | val_loss=0.448722 | val_bit_loss=0.638850 | val_snr_sym=19.0128 dB | val_ber=3.429362e-01 | best_train_snr=11.9834 dB @ 10 | best_val_snr=19.0128 dB @ 10 | a1=4.0094 | b1=1.1943 | a2=3.9918 | b2=1.0049 | k=0.9970
# step   20 | train_loss=0.386278 | bit_loss=0.587668 | snr_sym=20.1390 dB | train_ber=2.968750e-01 | val_loss=0.406078 | val_bit_loss=0.586309 | val_snr_sym=18.0231 dB | val_ber=2.951497e-01 | best_train_snr=24.9618 dB @ 17 | best_val_snr=19.0128 dB @ 10 | a1=4.0189 | b1=1.1933 | a2=3.9891 | b2=1.0021 | k=1.0008
# step   30 | train_loss=0.214293 | bit_loss=0.536244 | snr_sym=32.1951 dB | train_ber=2.868164e-01 | val_loss=0.377838 | val_bit_loss=0.552261 | val_snr_sym=17.4422 dB | val_ber=2.822428e-01 | best_train_snr=32.1951 dB @ 30 | best_val_snr=19.0128 dB @ 10 | a1=4.0276 | b1=1.1963 | a2=3.9936 | b2=0.9975 | k=1.0058
# step   40 | train_loss=0.314818 | bit_loss=0.524477 | snr_sym=20.9659 dB | train_ber=2.747721e-01 | val_loss=0.211283 | val_bit_loss=0.512619 | val_snr_sym=30.1336 dB | val_ber=2.761719e-01 | best_train_snr=32.7361 dB @ 36 | best_val_snr=30.1336 dB @ 40 | a1=4.0349 | b1=1.1963 | a2=3.9991 | b2=0.9930 | k=1.0103
# step   50 | train_loss=0.181606 | bit_loss=0.490400 | snr_sym=30.8794 dB | train_ber=2.675618e-01 | val_loss=0.233534 | val_bit_loss=0.492681 | val_snr_sym=25.9147 dB | val_ber=2.626953e-01 | best_train_snr=32.7361 dB @ 36 | best_val_snr=30.1336 dB @ 40 | a1=4.0398 | b1=1.1968 | a2=4.0049 | b2=0.9898 | k=1.0136
# step   60 | train_loss=0.205460 | bit_loss=0.471688 | snr_sym=26.6228 dB | train_ber=2.632650e-01 | val_loss=0.193454 | val_bit_loss=0.470858 | val_snr_sym=27.7403 dB | val_ber=2.644368e-01 | best_train_snr=32.7361 dB @ 36 | best_val_snr=30.1336 dB @ 40 | a1=4.0435 | b1=1.1978 | a2=4.0093 | b2=0.9874 | k=1.0160
# step   70 | train_loss=0.239599 | bit_loss=0.466925 | snr_sym=22.7325 dB | train_ber=2.841309e-01 | val_loss=0.173627 | val_bit_loss=0.461963 | val_snr_sym=28.8335 dB | val_ber=2.775879e-01 | best_train_snr=32.7361 dB @ 36 | best_val_snr=30.1336 dB @ 40 | a1=4.0506 | b1=1.1973 | a2=4.0171 | b2=0.9831 | k=1.0206
# step   80 | train_loss=0.116714 | bit_loss=0.448457 | snr_sym=33.1743 dB | train_ber=2.645671e-01 | val_loss=0.110094 | val_bit_loss=0.446651 | val_snr_sym=33.6557 dB | val_ber=2.548177e-01 | best_train_snr=33.1743 dB @ 80 | best_val_snr=33.6557 dB @ 80 | a1=4.0638 | b1=1.1996 | a2=4.0303 | b2=0.9749 | k=1.0291
# step   90 | train_loss=0.099711 | bit_loss=0.433132 | snr_sym=33.3420 dB | train_ber=2.568848e-01 | val_loss=0.096334 | val_bit_loss=0.431631 | val_snr_sym=33.5297 dB | val_ber=2.588379e-01 | best_train_snr=34.1233 dB @ 87 | best_val_snr=33.6557 dB @ 80 | a1=4.0809 | b1=1.2022 | a2=4.0480 | b2=0.9638 | k=1.0404
# step  100 | train_loss=0.067384 | bit_loss=0.418059 | snr_sym=35.0676 dB | train_ber=2.409342e-01 | val_loss=0.080856 | val_bit_loss=0.416356 | val_snr_sym=33.5500 dB | val_ber=2.427572e-01 | best_train_snr=35.7537 dB @ 97 | best_val_snr=33.6557 dB @ 80 | a1=4.0984 | b1=1.1997 | a2=4.0642 | b2=0.9529 | k=1.0517
# step  110 | train_loss=0.061584 | bit_loss=0.398212 | snr_sym=33.6628 dB | train_ber=2.399577e-01 | val_loss=0.054351 | val_bit_loss=0.396489 | val_snr_sym=34.2138 dB | val_ber=2.353841e-01 | best_train_snr=35.7537 dB @ 97 | best_val_snr=34.2138 dB @ 110 | a1=4.1149 | b1=1.1966 | a2=4.0746 | b2=0.9427 | k=1.0623
# step  120 | train_loss=0.051460 | bit_loss=0.377477 | snr_sym=32.6016 dB | train_ber=1.986491e-01 | val_loss=0.017308 | val_bit_loss=0.374084 | val_snr_sym=35.6776 dB | val_ber=1.941732e-01 | best_train_snr=35.7537 dB @ 97 | best_val_snr=35.6776 dB @ 120 | a1=4.1298 | b1=1.1977 | a2=4.0838 | b2=0.9337 | k=1.0717
# step  130 | train_loss=0.006978 | bit_loss=0.353631 | snr_sym=34.6653 dB | train_ber=1.737305e-01 | val_loss=0.005231 | val_bit_loss=0.351743 | val_snr_sym=34.6512 dB | val_ber=1.649089e-01 | best_train_snr=35.7537 dB @ 97 | best_val_snr=35.6776 dB @ 120 | a1=4.1433 | b1=1.2003 | a2=4.0923 | b2=0.9259 | k=1.0800
# step  140 | train_loss=-0.016711 | bit_loss=0.331963 | snr_sym=34.8674 dB | train_ber=1.647786e-01 | val_loss=-0.008694 | val_bit_loss=0.329819 | val_snr_sym=33.8513 dB | val_ber=1.672201e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.1570 | b1=1.2000 | a2=4.1022 | b2=0.9179 | k=1.0885
# step  150 | train_loss=-0.029929 | bit_loss=0.313047 | snr_sym=34.2976 dB | train_ber=1.585286e-01 | val_loss=-0.030524 | val_bit_loss=0.312487 | val_snr_sym=34.3011 dB | val_ber=1.628906e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.1696 | b1=1.1996 | a2=4.1131 | b2=0.9111 | k=1.0964
# step  160 | train_loss=-0.051699 | bit_loss=0.296533 | snr_sym=34.8233 dB | train_ber=1.427572e-01 | val_loss=-0.048242 | val_bit_loss=0.294836 | val_snr_sym=34.3078 dB | val_ber=1.447266e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.1811 | b1=1.1994 | a2=4.1268 | b2=0.9045 | k=1.1038
# step  170 | train_loss=-0.061207 | bit_loss=0.282134 | snr_sym=34.3340 dB | train_ber=1.462240e-01 | val_loss=-0.063161 | val_bit_loss=0.280886 | val_snr_sym=34.4046 dB | val_ber=1.449870e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.1922 | b1=1.2001 | a2=4.1422 | b2=0.8979 | k=1.1110
# step  180 | train_loss=-0.084861 | bit_loss=0.269831 | snr_sym=35.4692 dB | train_ber=1.330404e-01 | val_loss=-0.071242 | val_bit_loss=0.268819 | val_snr_sym=34.0060 dB | val_ber=1.361165e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2034 | b1=1.1986 | a2=4.1580 | b2=0.8915 | k=1.1183
# step  190 | train_loss=-0.097046 | bit_loss=0.258577 | snr_sym=35.5623 dB | train_ber=1.328125e-01 | val_loss=-0.098324 | val_bit_loss=0.257584 | val_snr_sym=35.5908 dB | val_ber=1.362793e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2145 | b1=1.1952 | a2=4.1731 | b2=0.8853 | k=1.1256
# step  200 | train_loss=-0.095706 | bit_loss=0.250450 | snr_sym=34.6156 dB | train_ber=1.344401e-01 | val_loss=-0.057293 | val_bit_loss=0.252910 | val_snr_sym=31.0203 dB | val_ber=1.235840e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2251 | b1=1.1929 | a2=4.1868 | b2=0.8792 | k=1.1326
# step  210 | train_loss=-0.104045 | bit_loss=0.242358 | snr_sym=34.6404 dB | train_ber=1.249512e-01 | val_loss=-0.104241 | val_bit_loss=0.241580 | val_snr_sym=34.5821 dB | val_ber=1.260905e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2351 | b1=1.1927 | a2=4.1987 | b2=0.8745 | k=1.1388
# step  220 | train_loss=-0.111520 | bit_loss=0.234923 | snr_sym=34.6443 dB | train_ber=1.213053e-01 | val_loss=-0.117839 | val_bit_loss=0.233820 | val_snr_sym=35.1659 dB | val_ber=1.224935e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2454 | b1=1.1933 | a2=4.2123 | b2=0.8707 | k=1.1446
# step  230 | train_loss=-0.119569 | bit_loss=0.227540 | snr_sym=34.7109 dB | train_ber=1.169271e-01 | val_loss=-0.095469 | val_bit_loss=0.227474 | val_snr_sym=32.2943 dB | val_ber=1.160645e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2558 | b1=1.1936 | a2=4.2252 | b2=0.8676 | k=1.1501
# step  240 | train_loss=-0.082219 | bit_loss=0.225830 | snr_sym=30.8049 dB | train_ber=1.074544e-01 | val_loss=-0.121147 | val_bit_loss=0.221941 | val_snr_sym=34.3088 dB | val_ber=1.077637e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2659 | b1=1.1970 | a2=4.2360 | b2=0.8642 | k=1.1555
# step  250 | train_loss=-0.131838 | bit_loss=0.216763 | snr_sym=34.8601 dB | train_ber=1.026042e-01 | val_loss=-0.127742 | val_bit_loss=0.216319 | val_snr_sym=34.4061 dB | val_ber=1.047852e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2749 | b1=1.1998 | a2=4.2476 | b2=0.8619 | k=1.1599
# step  260 | train_loss=-0.139463 | bit_loss=0.210058 | snr_sym=34.9521 dB | train_ber=9.612630e-02 | val_loss=-0.140251 | val_bit_loss=0.209555 | val_snr_sym=34.9807 dB | val_ber=9.847005e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2844 | b1=1.2018 | a2=4.2600 | b2=0.8594 | k=1.1648
# step  270 | train_loss=-0.129574 | bit_loss=0.206263 | snr_sym=33.5837 dB | train_ber=9.249674e-02 | val_loss=-0.143402 | val_bit_loss=0.205795 | val_snr_sym=34.9197 dB | val_ber=9.335937e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.2935 | b1=1.2024 | a2=4.2735 | b2=0.8582 | k=1.1690
# step  280 | train_loss=-0.132260 | bit_loss=0.199802 | snr_sym=33.2062 dB | train_ber=9.235026e-02 | val_loss=-0.142588 | val_bit_loss=0.199442 | val_snr_sym=34.2030 dB | val_ber=9.427083e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.3022 | b1=1.2048 | a2=4.2849 | b2=0.8571 | k=1.1732
# step  290 | train_loss=-0.137911 | bit_loss=0.193908 | snr_sym=33.1819 dB | train_ber=8.976237e-02 | val_loss=-0.163436 | val_bit_loss=0.192435 | val_snr_sym=35.5870 dB | val_ber=8.678385e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.3116 | b1=1.2091 | a2=4.2961 | b2=0.8558 | k=1.1777
# step  300 | train_loss=-0.166152 | bit_loss=0.190387 | snr_sym=35.6540 dB | train_ber=8.203125e-02 | val_loss=-0.152866 | val_bit_loss=0.189670 | val_snr_sym=34.2536 dB | val_ber=8.691406e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.3198 | b1=1.2096 | a2=4.3068 | b2=0.8554 | k=1.1811
# step  310 | train_loss=-0.158860 | bit_loss=0.184232 | snr_sym=34.3091 dB | train_ber=8.492839e-02 | val_loss=-0.145633 | val_bit_loss=0.183682 | val_snr_sym=32.9315 dB | val_ber=8.567708e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.3282 | b1=1.2119 | a2=4.3167 | b2=0.8557 | k=1.1843
# step  320 | train_loss=-0.175154 | bit_loss=0.177997 | snr_sym=35.3151 dB | train_ber=8.108724e-02 | val_loss=-0.161715 | val_bit_loss=0.177689 | val_snr_sym=33.9404 dB | val_ber=8.429362e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.6776 dB @ 120 | a1=4.3378 | b1=1.2136 | a2=4.3274 | b2=0.8562 | k=1.1878
# step  330 | train_loss=-0.176549 | bit_loss=0.171837 | snr_sym=34.8386 dB | train_ber=8.282878e-02 | val_loss=-0.186111 | val_bit_loss=0.171516 | val_snr_sym=35.7626 dB | val_ber=8.287760e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3477 | b1=1.2134 | a2=4.3388 | b2=0.8566 | k=1.1913
# step  340 | train_loss=-0.155002 | bit_loss=0.178654 | snr_sym=33.3656 dB | train_ber=8.792318e-02 | val_loss=-0.123793 | val_bit_loss=0.200418 | val_snr_sym=32.4210 dB | val_ber=1.073242e-01 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3552 | b1=1.2125 | a2=4.3498 | b2=0.8578 | k=1.1937
# step  350 | train_loss=-0.134922 | bit_loss=0.195372 | snr_sym=33.0294 dB | train_ber=9.326172e-02 | val_loss=-0.120935 | val_bit_loss=0.205672 | val_snr_sym=32.6607 dB | val_ber=9.733073e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3591 | b1=1.2123 | a2=4.3561 | b2=0.8587 | k=1.1949
# step  360 | train_loss=-0.172334 | bit_loss=0.167437 | snr_sym=33.9771 dB | train_ber=7.623698e-02 | val_loss=-0.171896 | val_bit_loss=0.168437 | val_snr_sym=34.0334 dB | val_ber=8.299154e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3630 | b1=1.2116 | a2=4.3632 | b2=0.8598 | k=1.1960
# step  370 | train_loss=-0.191703 | bit_loss=0.161613 | snr_sym=35.3316 dB | train_ber=7.485352e-02 | val_loss=-0.175287 | val_bit_loss=0.161780 | val_snr_sym=33.7068 dB | val_ber=7.825521e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3701 | b1=1.2090 | a2=4.3754 | b2=0.8617 | k=1.1983
# step  380 | train_loss=-0.201850 | bit_loss=0.156575 | snr_sym=35.8425 dB | train_ber=7.316081e-02 | val_loss=-0.177678 | val_bit_loss=0.156735 | val_snr_sym=33.4413 dB | val_ber=7.244466e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3783 | b1=1.2061 | a2=4.3900 | b2=0.8644 | k=1.2007
# step  390 | train_loss=-0.189287 | bit_loss=0.152354 | snr_sym=34.1641 dB | train_ber=6.990560e-02 | val_loss=-0.173675 | val_bit_loss=0.152749 | val_snr_sym=32.6424 dB | val_ber=7.320964e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3876 | b1=1.2042 | a2=4.4040 | b2=0.8657 | k=1.2040
# step  400 | train_loss=-0.186108 | bit_loss=0.149015 | snr_sym=33.5123 dB | train_ber=6.744792e-02 | val_loss=-0.193601 | val_bit_loss=0.148872 | val_snr_sym=34.2473 dB | val_ber=6.658529e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.3969 | b1=1.2037 | a2=4.4179 | b2=0.8670 | k=1.2075
# step  410 | train_loss=-0.186226 | bit_loss=0.145483 | snr_sym=33.1709 dB | train_ber=6.412760e-02 | val_loss=-0.187234 | val_bit_loss=0.144593 | val_snr_sym=33.1827 dB | val_ber=6.507161e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4061 | b1=1.2001 | a2=4.4322 | b2=0.8700 | k=1.2104
# step  420 | train_loss=-0.207719 | bit_loss=0.141788 | snr_sym=34.9507 dB | train_ber=5.984701e-02 | val_loss=-0.189312 | val_bit_loss=0.142531 | val_snr_sym=33.1843 dB | val_ber=6.160482e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4132 | b1=1.1978 | a2=4.4440 | b2=0.8728 | k=1.2128
# step  430 | train_loss=-0.207901 | bit_loss=0.137646 | snr_sym=34.5547 dB | train_ber=5.869141e-02 | val_loss=-0.204283 | val_bit_loss=0.137649 | val_snr_sym=34.1932 dB | val_ber=5.917969e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4211 | b1=1.1970 | a2=4.4550 | b2=0.8752 | k=1.2155
# step  440 | train_loss=-0.197546 | bit_loss=0.135163 | snr_sym=33.2709 dB | train_ber=5.680339e-02 | val_loss=-0.211527 | val_bit_loss=0.133848 | val_snr_sym=34.5375 dB | val_ber=5.760091e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4299 | b1=1.1963 | a2=4.4672 | b2=0.8778 | k=1.2189
# step  450 | train_loss=-0.215119 | bit_loss=0.130715 | snr_sym=34.5834 dB | train_ber=5.600586e-02 | val_loss=-0.204542 | val_bit_loss=0.131356 | val_snr_sym=33.5898 dB | val_ber=5.683594e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4386 | b1=1.1922 | a2=4.4813 | b2=0.8823 | k=1.2214
# step  460 | train_loss=-0.203272 | bit_loss=0.135371 | snr_sym=33.8643 dB | train_ber=6.106771e-02 | val_loss=-0.209923 | val_bit_loss=0.128756 | val_snr_sym=33.8680 dB | val_ber=5.675456e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4460 | b1=1.1908 | a2=4.4921 | b2=0.8854 | k=1.2239
# step  470 | train_loss=-0.210584 | bit_loss=0.128383 | snr_sym=33.8967 dB | train_ber=5.362956e-02 | val_loss=-0.218714 | val_bit_loss=0.128925 | val_snr_sym=34.7640 dB | val_ber=5.843099e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4524 | b1=1.1904 | a2=4.5012 | b2=0.8880 | k=1.2260
# step  480 | train_loss=-0.213149 | bit_loss=0.126098 | snr_sym=33.9247 dB | train_ber=6.184896e-02 | val_loss=-0.218716 | val_bit_loss=0.123819 | val_snr_sym=34.2536 dB | val_ber=5.861003e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4598 | b1=1.1901 | a2=4.5123 | b2=0.8909 | k=1.2286
# step  490 | train_loss=-0.221057 | bit_loss=0.121662 | snr_sym=34.2719 dB | train_ber=5.502930e-02 | val_loss=-0.218424 | val_bit_loss=0.121199 | val_snr_sym=33.9623 dB | val_ber=5.559896e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4681 | b1=1.1894 | a2=4.5249 | b2=0.8944 | k=1.2313
# step  500 | train_loss=-0.221033 | bit_loss=0.118020 | snr_sym=33.9053 dB | train_ber=5.388997e-02 | val_loss=-0.227932 | val_bit_loss=0.118346 | val_snr_sym=34.6278 dB | val_ber=5.374349e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4765 | b1=1.1878 | a2=4.5389 | b2=0.8996 | k=1.2331
# step  510 | train_loss=-0.227435 | bit_loss=0.116064 | snr_sym=34.3499 dB | train_ber=5.387370e-02 | val_loss=-0.228810 | val_bit_loss=0.115820 | val_snr_sym=34.4631 dB | val_ber=5.402018e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4848 | b1=1.1867 | a2=4.5531 | b2=0.9052 | k=1.2348
# step  520 | train_loss=-0.217009 | bit_loss=0.115148 | snr_sym=33.2157 dB | train_ber=5.278320e-02 | val_loss=-0.230548 | val_bit_loss=0.113113 | val_snr_sym=34.3661 dB | val_ber=5.380859e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.4931 | b1=1.1850 | a2=4.5675 | b2=0.9112 | k=1.2364
# step  530 | train_loss=-0.225042 | bit_loss=0.112181 | snr_sym=33.7223 dB | train_ber=5.460612e-02 | val_loss=-0.216471 | val_bit_loss=0.112220 | val_snr_sym=32.8691 dB | val_ber=5.371094e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.5018 | b1=1.1831 | a2=4.5813 | b2=0.9166 | k=1.2381
# step  540 | train_loss=-0.223883 | bit_loss=0.110697 | snr_sym=33.4580 dB | train_ber=5.257161e-02 | val_loss=-0.239286 | val_bit_loss=0.108786 | val_snr_sym=34.8073 dB | val_ber=5.385742e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.5106 | b1=1.1837 | a2=4.5944 | b2=0.9208 | k=1.2406
# step  550 | train_loss=-0.228554 | bit_loss=0.115533 | snr_sym=34.4088 dB | train_ber=5.022786e-02 | val_loss=-0.221187 | val_bit_loss=0.116505 | val_snr_sym=33.7691 dB | val_ber=5.870768e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=35.7626 dB @ 330 | a1=4.5190 | b1=1.1855 | a2=4.6051 | b2=0.9231 | k=1.2439
# step  560 | train_loss=-0.150255 | bit_loss=0.137354 | snr_sym=28.7609 dB | train_ber=6.137695e-02 | val_loss=-0.254208 | val_bit_loss=0.112801 | val_snr_sym=36.7009 dB | val_ber=4.996745e-02 | best_train_snr=35.9505 dB @ 137 | best_val_snr=36.7009 dB @ 560 | a1=4.5240 | b1=1.1866 | a2=4.6117 | b2=0.9245 | k=1.2458
# step  570 | train_loss=-0.219428 | bit_loss=0.117601 | snr_sym=33.7029 dB | train_ber=5.164388e-02 | val_loss=-0.221066 | val_bit_loss=0.113279 | val_snr_sym=33.4345 dB | val_ber=5.538737e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5286 | b1=1.1870 | a2=4.6176 | b2=0.9257 | k=1.2474
# step  580 | train_loss=-0.217311 | bit_loss=0.106791 | snr_sym=32.4102 dB | train_ber=5.224609e-02 | val_loss=-0.226177 | val_bit_loss=0.107897 | val_snr_sym=33.4074 dB | val_ber=5.458984e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5339 | b1=1.1878 | a2=4.6250 | b2=0.9280 | k=1.2489
# step  590 | train_loss=-0.230321 | bit_loss=0.104290 | snr_sym=33.4611 dB | train_ber=5.169271e-02 | val_loss=-0.245088 | val_bit_loss=0.103452 | val_snr_sym=34.8540 dB | val_ber=5.172526e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5413 | b1=1.1912 | a2=4.6360 | b2=0.9315 | k=1.2509
# step  600 | train_loss=-0.236291 | bit_loss=0.101484 | snr_sym=33.7775 dB | train_ber=4.842122e-02 | val_loss=-0.233086 | val_bit_loss=0.102027 | val_snr_sym=33.5113 dB | val_ber=4.825846e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5495 | b1=1.1927 | a2=4.6486 | b2=0.9358 | k=1.2531
# step  610 | train_loss=-0.230010 | bit_loss=0.100220 | snr_sym=33.0230 dB | train_ber=5.008138e-02 | val_loss=-0.226688 | val_bit_loss=0.100999 | val_snr_sym=32.7687 dB | val_ber=4.959310e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5584 | b1=1.1957 | a2=4.6610 | b2=0.9395 | k=1.2558
# step  620 | train_loss=-0.234096 | bit_loss=0.099073 | snr_sym=33.3170 dB | train_ber=4.920247e-02 | val_loss=-0.234718 | val_bit_loss=0.099045 | val_snr_sym=33.3763 dB | val_ber=4.812826e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5674 | b1=1.1966 | a2=4.6739 | b2=0.9436 | k=1.2584
# step  630 | train_loss=-0.242097 | bit_loss=0.096871 | snr_sym=33.8967 dB | train_ber=4.770508e-02 | val_loss=-0.227983 | val_bit_loss=0.097883 | val_snr_sym=32.5866 dB | val_ber=4.777018e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5762 | b1=1.1984 | a2=4.6870 | b2=0.9479 | k=1.2608
# step  640 | train_loss=-0.244599 | bit_loss=0.094874 | snr_sym=33.9473 dB | train_ber=4.799805e-02 | val_loss=-0.251210 | val_bit_loss=0.094577 | val_snr_sym=34.5786 dB | val_ber=4.941406e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5848 | b1=1.1990 | a2=4.7005 | b2=0.9532 | k=1.2624
# step  650 | train_loss=-0.252451 | bit_loss=0.093215 | snr_sym=34.5667 dB | train_ber=4.653320e-02 | val_loss=-0.255982 | val_bit_loss=0.093343 | val_snr_sym=34.9325 dB | val_ber=4.759115e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5931 | b1=1.1999 | a2=4.7145 | b2=0.9586 | k=1.2641
# step  660 | train_loss=-0.208874 | bit_loss=0.121255 | snr_sym=33.0129 dB | train_ber=6.061198e-02 | val_loss=-0.159923 | val_bit_loss=0.128851 | val_snr_sym=28.8775 dB | val_ber=5.901693e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.5997 | b1=1.2016 | a2=4.7247 | b2=0.9622 | k=1.2657
# step  670 | train_loss=-0.189530 | bit_loss=0.118571 | snr_sym=30.8101 dB | train_ber=5.717773e-02 | val_loss=-0.101999 | val_bit_loss=0.160293 | val_snr_sym=26.2292 dB | val_ber=7.537435e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6029 | b1=1.2024 | a2=4.7297 | b2=0.9640 | k=1.2666
# step  680 | train_loss=-0.146476 | bit_loss=0.133312 | snr_sym=27.9788 dB | train_ber=5.948893e-02 | val_loss=0.053007 | val_bit_loss=0.261341 | val_snr_sym=20.8334 dB | val_ber=1.086914e-01 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6050 | b1=1.2031 | a2=4.7328 | b2=0.9650 | k=1.2672
# step  690 | train_loss=-0.232379 | bit_loss=0.108916 | snr_sym=34.1295 dB | train_ber=4.887695e-02 | val_loss=-0.243798 | val_bit_loss=0.097847 | val_snr_sym=34.1645 dB | val_ber=4.490560e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6068 | b1=1.2038 | a2=4.7352 | b2=0.9656 | k=1.2679
# step  700 | train_loss=-0.227272 | bit_loss=0.100356 | snr_sym=32.7628 dB | train_ber=4.920247e-02 | val_loss=-0.238235 | val_bit_loss=0.097367 | val_snr_sym=33.5603 dB | val_ber=4.570312e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6104 | b1=1.2050 | a2=4.7396 | b2=0.9666 | k=1.2693
# step  710 | train_loss=-0.243285 | bit_loss=0.092414 | snr_sym=33.5699 dB | train_ber=4.462891e-02 | val_loss=-0.258296 | val_bit_loss=0.091360 | val_snr_sym=34.9656 dB | val_ber=4.275716e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6161 | b1=1.2103 | a2=4.7468 | b2=0.9680 | k=1.2717
# step  720 | train_loss=-0.250871 | bit_loss=0.088791 | snr_sym=33.9662 dB | train_ber=4.194336e-02 | val_loss=-0.247767 | val_bit_loss=0.089293 | val_snr_sym=33.7060 dB | val_ber=4.344076e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6243 | b1=1.2166 | a2=4.7565 | b2=0.9706 | k=1.2745
# step  730 | train_loss=-0.263597 | bit_loss=0.087219 | snr_sym=35.0816 dB | train_ber=4.275716e-02 | val_loss=-0.245432 | val_bit_loss=0.088352 | val_snr_sym=33.3784 dB | val_ber=4.269206e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6331 | b1=1.2229 | a2=4.7676 | b2=0.9743 | k=1.2773
# step  740 | train_loss=-0.257701 | bit_loss=0.085976 | snr_sym=34.3677 dB | train_ber=3.994141e-02 | val_loss=-0.247202 | val_bit_loss=0.087269 | val_snr_sym=33.4471 dB | val_ber=4.259440e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6422 | b1=1.2261 | a2=4.7796 | b2=0.9790 | k=1.2795
# step  750 | train_loss=-0.249847 | bit_loss=0.085296 | snr_sym=33.5144 dB | train_ber=3.972982e-02 | val_loss=-0.258951 | val_bit_loss=0.084447 | val_snr_sym=34.3398 dB | val_ber=3.912760e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6517 | b1=1.2276 | a2=4.7914 | b2=0.9834 | k=1.2821
# step  760 | train_loss=-0.263678 | bit_loss=0.083077 | snr_sym=34.6755 dB | train_ber=3.857422e-02 | val_loss=-0.245656 | val_bit_loss=0.084233 | val_snr_sym=32.9890 dB | val_ber=4.025065e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6614 | b1=1.2301 | a2=4.8030 | b2=0.9871 | k=1.2853
# step  770 | train_loss=-0.269891 | bit_loss=0.081423 | snr_sym=35.1314 dB | train_ber=3.865560e-02 | val_loss=-0.259171 | val_bit_loss=0.081801 | val_snr_sym=34.0972 dB | val_ber=3.873698e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6712 | b1=1.2342 | a2=4.8141 | b2=0.9904 | k=1.2886
# step  780 | train_loss=-0.257123 | bit_loss=0.081106 | snr_sym=33.8228 dB | train_ber=3.912760e-02 | val_loss=-0.266506 | val_bit_loss=0.080714 | val_snr_sym=34.7220 dB | val_ber=3.816732e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6812 | b1=1.2384 | a2=4.8248 | b2=0.9931 | k=1.2924
# step  790 | train_loss=-0.255877 | bit_loss=0.082101 | snr_sym=33.7979 dB | train_ber=3.901367e-02 | val_loss=-0.252560 | val_bit_loss=0.080586 | val_snr_sym=33.3146 dB | val_ber=3.834635e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6906 | b1=1.2423 | a2=4.8361 | b2=0.9966 | k=1.2956
# step  800 | train_loss=-0.251471 | bit_loss=0.078910 | snr_sym=33.0380 dB | train_ber=3.528646e-02 | val_loss=-0.278098 | val_bit_loss=0.077181 | val_snr_sym=35.5278 dB | val_ber=3.240560e-02 | best_train_snr=36.1331 dB @ 564 | best_val_snr=36.7009 dB @ 560 | a1=4.6989 | b1=1.2436 | a2=4.8480 | b2=1.0028 | k=1.2966
#
# Training finished.
# Best train snr_sym = 36.1331 dB at step 564
# Best val   snr_sym = 36.7009 dB at step 560
# Best val   BER     = 3.240560e-02 at step 800

# %%
plt.figure(figsize=(7,4.5))



best_step = history_e2e["best_train_snr_sym_step"]
best_loss = history_e2e["loss"][best_step - 1]
plt.scatter(best_step, best_loss, s=80, marker="*",c="#FF0000", label="best snr_sym step",zorder=5)
plt.plot(history_e2e["loss"])
plt.annotate(
    f"step={best_step}\nloss={best_loss:.4f}",
    (best_step, best_loss),
    textcoords="offset points",
    xytext=(8, 8)
)

plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training loss")
plt.grid(True)
plt.legend()
plt.show()


plt.figure(figsize=(7,4.5))
plt.plot(history_e2e["snr_sym_db"])

best_step = history_e2e["best_train_snr_sym_step"]
best_snr = history_e2e["best_train_snr_sym_db"]

plt.scatter(best_step, best_snr, s=100, marker="*", label="best point", c="#FF0000", zorder=5)
plt.annotate(
    f"({best_step}, {best_snr:.2f} dB)",
    (best_step, best_snr),
    textcoords="offset points",
    xytext=(8, 8)
)

plt.xlabel("Step")
plt.ylabel("snr_sym (dB)")
plt.title("snr_sym during training")
plt.grid(True)
plt.legend()
plt.show()


plt.figure(figsize=(7, 4))
plt.plot(history_e2e["a1"], label="a1")
plt.plot(history_e2e["b1"], label="b1")
plt.plot(history_e2e["a2"], label="a2")
plt.plot(history_e2e["b2"], label="b2")
plt.plot(history_e2e["k"], label="k")
plt.xlabel("step")
plt.ylabel("value")
plt.legend()
plt.axvline(best_step, linestyle="--", linewidth=1.5, label="best snr_sym step")
best_k = history_e2e["k"][best_step - 1]
# plt.scatter(best_step, best_k, s=100, marker="*", label="best point", c="#FF0000", zorder=5)
best_a1 = history_e2e["a1"][best_step - 1]
best_b1 = history_e2e["b1"][best_step - 1]
best_a2 = history_e2e["a2"][best_step - 1]
best_b2 = history_e2e["b2"][best_step - 1]
# plt.scatter(best_step, best_a1, s=100, marker="*", label="best a1", c="#0000FF", zorder=5)
# plt.scatter(best_step, best_b1, s=100, marker="*", label="best b1", c="#00FF00", zorder=5)
# plt.scatter(best_step, best_a2, s=100, marker="*", label="best a2", c="#FFA500", zorder=5)
# plt.scatter(best_step, best_b2, s=100, marker="*", label="best b2", c="#800080", zorder=5)

plt.title("Learned physical parameters")
plt.show()
print(best_a1, best_b1, best_a2, best_b2, best_k)
# Out:
# 4.840021728007645 1.5939694309080963 4.574452036453063 0.7466789664561418 1.3582085086446427

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 4))
plt.plot(history_e2e["loss"], label="total loss")
plt.plot(history_e2e["bit_loss"], label="bit loss")
plt.xlabel("step")
plt.ylabel("loss")
plt.legend()
plt.title("E2E joint loss")
plt.show()

plt.figure(figsize=(7, 4))
plt.plot(history_e2e["val_loss"], label="validation loss")
plt.plot(history_e2e["val_bit_loss"], label="validation bit loss")
plt.xlabel("step")
plt.ylabel("loss")
plt.legend()
plt.title("E2E joint loss")
plt.show()

plt.figure(figsize=(7, 4))
plt.plot(history_e2e["val_snr_sym_db"], label="validation SNR")
plt.xlabel("step")
plt.ylabel("SNR (dB)")
plt.legend()
plt.title("E2E joint loss")
plt.show()

plt.figure(figsize=(7, 4))
plt.plot(history_e2e["snr_sym_db"], label="train SNR_sym (dB)")
plt.xlabel("step")
plt.ylabel("SNR (dB)")
plt.legend()
plt.title("Train symbol-level SNR after OFDM demod")
plt.show()

plt.figure(figsize=(7, 4))
plt.plot(history_e2e["ber"], label="train BER")
plt.xlabel("step")
plt.ylabel("BER")
plt.legend()
plt.title("Train BER")
plt.show()

plt.figure(figsize=(7, 4))

plt.plot(history_e2e["a1"], label="a1")
plt.plot(history_e2e["b1"], label="b1")
plt.plot(history_e2e["a2"], label="a2")
plt.plot(history_e2e["b2"], label="b2")
plt.plot(history_e2e["k"], label="k")
plt.xlabel("step")
plt.ylabel("value")
plt.legend()
plt.title("Learned physical parameters")
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.plot(history_e2e["loss"], label="train loss")
plt.xlabel("step")
plt.ylabel("BCE loss")
plt.legend()
plt.title("E2E neural modem training loss")
plt.show()

plt.figure(figsize=(7, 4))
plt.plot(history_e2e["ber"], label="train BER")
plt.xlabel("step")
plt.ylabel("BER")
plt.legend()
plt.title("E2E neural modem train BER")
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.plot(history_e2e["a1"], label="a1")
plt.plot(history_e2e["b1"], label="b1")
plt.plot(history_e2e["a2"], label="a2")
plt.plot(history_e2e["b2"], label="b2")
plt.plot(history_e2e["k"], label="k")
plt.xlabel("step")
plt.ylabel("value")
plt.legend()
plt.title("Parameter trajectories")
plt.show()

# %%
plot_learned_constellation(
    e2e_model.mapper,
    ml=e2e_model.ml,
    annotate=True,
    title="Learned Neural Constellation"
)

# %%
#2026/4/6/18:52
#当loss不写入SNR时效果也不错。起始值比较重要，明天开始写intro加继续研究起始值的问题。
